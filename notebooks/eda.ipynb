# %%
import pandas as pd
import numpy
df = pd.read_csv("Visadataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame
print(df.isnull().sum())  # Check for missing values

# Convert data types
df['case_id'] = df['case_id'].astype(int)
df['yr_of_estab'] = df['yr_of_estab'].astype('category')
df['no_of_employees'] = df['no_of_employees'].astype('category')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Numerical columns
numerical_cols = ['prevailing_wage', 'no_of_employees', 'yr_of_estab']

for col in numerical_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

    print(df[col].describe())

# Categorical columns
categorical_cols = ['continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']

for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=df[col])
    plt.title(f'Distribution of {col}')
    plt.show()

    print(df[col].value_counts())
# Out:
# count     25480.000000
# mean      74455.814592
# std       52815.942327
# min           2.136700
# 25%       34015.480000
# 50%       70308.210000
# 75%      107735.512500
# max      319210.270000
# Name: prevailing_wage, dtype: float64
# count     25480.000000
# mean       5667.043210
# std       22877.928848
# min         -26.000000
# 25%        1022.000000
# 50%        2109.000000
# 75%        3504.000000
# max      602069.000000
# Name: no_of_employees, dtype: float64
# count    25480.000000
# mean      1979.409929
# std         42.366929
# min       1800.000000
# 25%       1976.000000
# 50%       1997.000000
# 75%       2005.000000
# max       2016.000000
# Name: yr_of_estab, dtype: float64
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# ...

# %%
from pandas import value_counts


for col in categorical_cols:
    print(df[col].value_counts(normalize=True)*100)
    print(20*'*')
# Out:
# continent
# Asia             66.173469
# Europe           14.646782
# North America    12.919937
# South America     3.343799
# Africa            2.162480
# Oceania           0.753532
# Name: proportion, dtype: float64
# ********************
# education_of_employee
# Bachelor's     40.164835
# Master's       37.810047
# High School    13.422292
# Doctorate       8.602826
# Name: proportion, dtype: float64
# ********************
# has_job_experience
# Y    58.092622
# N    41.907378
# Name: proportion, dtype: float64
# ********************
# requires_job_training
# N    88.402669
# Y    11.597331
# Name: proportion, dtype: float64
# ********************
# region_of_employment
# Northeast    28.237834
# South        27.539246
# West         25.847724
# Midwest      16.903454
# Island        1.471743
# Name: proportion, dtype: float64
# ********************
# unit_of_wage
# Year     90.117739
# Hour      8.465463
# Week      1.067504
# Month     0.349294
# ...

# %% [markdown]
# * A scatter plot showing the relationship between prevailing_wage and no_of_employees.
# *  A box plot showing the distribution of prevailing_wage for each category of education_of_employee.
# *  A violin plot showing the distribution of prevailing_wage for each category of region_of_employment

# %%
import plotly.express as px

# Scatter plot: prevailing_wage vs no_of_employees
fig = px.scatter(df, x='no_of_employees', y='prevailing_wage', trendline='ols')
fig.update_layout(title='Prevailing Wage vs No of Employees')
fig.write_image("prevailing_wage_vs_no_of_employees.png")

# Correlation coefficient
corr_coef = df['prevailing_wage'].corr(df['no_of_employees'])
print(f'Correlation Coefficient: {corr_coef:.2f}')

# Box plot: prevailing_wage vs education_of_employee
fig = px.box(df, x='education_of_employee', y='prevailing_wage')
fig.update_layout(title='Prevailing Wage vs Education of Employee')
fig.write_image("prevailing_wage_vs_education_of_employee.png")

# Violin plot: prevailing_wage vs region_of_employment
fig = px.violin(df, x='region_of_employment', y='prevailing_wage')
fig.update_layout(title='Prevailing Wage vs Region of Employment')
fig.write_image("prevailing_wage_vs_region_of_employment.png")
# Out:
# Correlation Coefficient: -0.01

# %% [markdown]
# # UNIVIRIATE ANALYSIS

# %%
from matplotlib import colors


plt.figure(figsize = (15,10))
plt.suptitle("univiriate analysis for numerical features")

for i in  range(0,len(numerical_cols)):
    plt.subplot(2,2,1+i)
    plt.grid()
    sns.kdeplot(x= df[numerical_cols[i]],color = "green")
    plt.xlabel(numerical_cols[i])
    plt.tight_layout()

# %%
plt.figure(figsize = (15,8))
plt.suptitle("univiriate analysis of categorical features")

for i in range(0,len(categorical_cols)):
    plt.subplot(3,3,i+1)
    sns.countplot(df[categorical_cols[i]])
    
    plt.xticks(rotation = 90)
    plt.tight_layout()
    plt.title(categorical_cols[i]+"_count")

# %% [markdown]
# # Biviriate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Bivariate analysis: prevailing_wage vs no_of_employees
plt.figure(figsize=(8, 6))
sns.scatterplot(x='no_of_employees', y='prevailing_wage', data=df)
plt.title('Prevailing Wage vs No of Employees')
plt.xlabel('No of Employees')
plt.ylabel('Prevailing Wage')
plt.show()
plt.savefig('bivariate_analysis_prevailing_wage_vs_no_of_employees.png')

# Bivariate analysis: prevailing_wage vs education_of_employee
plt.figure(figsize=(8, 6))
sns.boxplot(x='education_of_employee', y='prevailing_wage', data=df)
plt.title('Prevailing Wage vs Education of Employee')
plt.xlabel('Education of Employee')
plt.ylabel('Prevailing Wage')
plt.show()
plt.savefig('bivariate_analysis_prevailing_wage_vs_education_of_employee.png')

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Multiviriate Analysis

# %%
# Multivariate analysis: prevailing_wage vs no_of_employees, education_of_employee, region_of_employment
plt.figure(figsize=(12, 10))
sns.lmplot(x='no_of_employees', y='prevailing_wage', hue='education_of_employee', col='region_of_employment', data=df)
plt.title('Prevailing Wage vs No of Employees, Education of Employee, Region of Employment')
plt.xlabel('No of Employees')
plt.ylabel('Prevailing Wage')
plt.savefig('multivariate_analysis_prevailing_wage_vs_no_of_employees_education_of_employee_region_of_employment.png')

# Multivariate analysis: prevailing_wage vs education_of_employee, region_of_employment, full_time_position
plt.figure(figsize=(12, 10))
sns.barplot(x='education_of_employee', y='prevailing_wage', hue='region_of_employment',  data=df)
plt.title('Prevailing Wage vs Education of Employee, Region of Employment, Full Time Position')
plt.xlabel('Education of Employee')
plt.ylabel('Prevailing Wage')
plt.savefig('multivariate_analysis_prevailing_wage_vs_education_of_employee_region_of_employment_full_time_position.png')

# Multivariate analysis: prevailing_wage vs no_of_employees, education_of_employee, has_job_experience
plt.figure(figsize=(12, 10))
sns.lmplot(x='no_of_employees', y='prevailing_wage', hue='education_of_employee', col='has_job_experience', data=df)
plt.title('Prevailing Wage vs No of Employees, Education of Employee, Has Job Experience')
plt.xlabel('No of Employees')
plt.ylabel('Prevailing Wage')
plt.savefig('multivariate_analysis_prevailing_wage_vs_no_of_employees_education_of_employee_has_job_experience.png')

# %%
# Multivariate analysis: prevailing_wage vs no_of_employees, education_of_employee
plt.figure(figsize=(10, 8))
sns.lmplot(x='no_of_employees', y='prevailing_wage', hue='education_of_employee', data=df)
plt.title('Prevailing Wage vs No of Employees, Education of Employee')
plt.xlabel('No of Employees')
plt.ylabel('Prevailing Wage')
plt.savefig('multivariate_analysis_prevailing_wage_vs_no_of_employees_education_of_employee.png')

# Multivariate analysis: prevailing_wage vs region_of_employment, education_of_employee
plt.figure(figsize=(10, 8))
sns.lmplot(x='region_of_employment', y='prevailing_wage', hue='education_of_employee', data=df)
plt.title('Prevailing Wage vs Region of Employment, Education of Employee')
plt.xlabel('Region of Employment')
plt.ylabel('Prevailing Wage')
plt.savefig('multivariate_analysis_prevailing_wage_vs_region_of_employment_education_of_employee.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 11
#       9 # Multivariate analysis: prevailing_wage vs region_of_employment, education_of_employee
#      10 plt.figure(figsize=(10, 8))
# ---> 11 sns.lmplot(x='region_of_employment', y='prevailing_wage', hue='education_of_employee', data=df)
#      12 plt.title('Prevailing Wage vs Region of Employment, Education of Employee')
#      13 plt.xlabel('Region of Employment')
#
# File c:\Users\riswa\anaconda3\envs\mlops\lib\site-packages\seaborn\regression.py:640, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
# ...

# %%
# discrete_features=[feature for feature in numerical_cols if len(df[feature].unique())<=25]

# continuous_features=[feature for feature in  categorical_cols if len(df[feature].unique()) > 25]

# print('We have {} discrete features : {}'.format(len(discrete_features), discrete_features))
# print('\nWe have {} continuous_features : {}'.format(len(continuous_features), continuous_features))

# %%
categorical_cols,numerical_cols
# Out:
# (['continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['prevailing_wage', 'no_of_employees', 'yr_of_estab'])

# %%
continuous_features =  ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
# Encode the 'education_of_employee' column
le = LabelEncoder()
df['education_of_employee_encoded'] = le.fit_transform(df['education_of_employee'])

# Select relevant columns for clustering
columns = ['prevailing_wage', 'no_of_employees', 'education_of_employee_encoded']

# Create a KMeans model with 3 clusters
kmeans = KMeans(n_clusters=3)

# Fit the model to the data
kmeans.fit(df[columns])

# Predict the cluster labels
labels = kmeans.labels_

# Plot the clusters
plt.scatter(df['prevailing_wage'], df['no_of_employees'], c=labels)
plt.title('KMeans Clustering')
plt.xlabel('Prevailing Wage')
plt.ylabel('No of Employees')
plt.savefig('clustering_analysis.png')

# %% [markdown]
# # checking for multicollinearity

# %%
from scipy.stats import chi2_contingency
chi2_test = []
for feature in categorical_cols:
    if chi2_contingency(pd.crosstab(df['case_status'], df[feature]))[1] < 0.05:
        chi2_test.append('Reject Null Hypothesis')
    else:
        chi2_test.append('Fail to Reject Null Hypothesis')
result = pd.DataFrame(data=[categorical_cols, chi2_test]).T
result.columns = ['Column', 'Hypothesis Result']
result
# Out:
#                   Column               Hypothesis Result
# 0              continent          Reject Null Hypothesis
# 1  education_of_employee          Reject Null Hypothesis
# 2     has_job_experience          Reject Null Hypothesis
# 3  requires_job_training  Fail to Reject Null Hypothesis
# 4   region_of_employment          Reject Null Hypothesis
# 5           unit_of_wage          Reject Null Hypothesis
# 6     full_time_position          Reject Null Hypothesis
# 7            case_status          Reject Null Hypothesis

# %%
import pandas as pd
from scipy.stats import chi2_contingency

continuous_features = ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

for feature in continuous_features:
    contingency_table = pd.crosstab(df['case_status'], pd.cut(df[feature], bins=10))
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    if p < 0.05:
        print(f"{feature} rejects the null hypothesis (p-value: {p:.4f})")
    else:
        print(f"{feature} fails to reject the null hypothesis (p-value: {p:.4f})")
# Out:
# no_of_employees fails to reject the null hypothesis (p-value: 0.7352)
# yr_of_estab fails to reject the null hypothesis (p-value: 0.1519)
# prevailing_wage rejects the null hypothesis (p-value: 0.0000)

# %%
import pandas as pd
from scipy.stats import chi2_contingency

results = []

for feature in df.columns:
    if df[feature].dtype == 'object':
        contingency_table = pd.crosstab(df['case_status'], df[feature])
        chi2, p, dof, expected = chi2_contingency(contingency_table)
    else:
        contingency_table = pd.crosstab(df['case_status'], pd.cut(df[feature], bins=10))
        chi2, p, dof, expected = chi2_contingency(contingency_table)
    
    if p < 0.05:
        result = 'Rejects null hypothesis'
    else:
        result = 'Fails to reject null hypothesis'
    
    results.append({'Feature': feature, 'p-value': p, 'Result': result})

results_df = pd.DataFrame(results)
results_df
# Out:
#                           Feature        p-value  \
# 0                         case_id   4.970546e-01
# 1                       continent   8.828798e-74
# 2           education_of_employee   0.000000e+00
# 3              has_job_experience  1.922560e-206
# 4           requires_job_training   1.855647e-01
# 5                 no_of_employees   7.351616e-01
# 6                     yr_of_estab   1.519053e-01
# 7            region_of_employment   2.338664e-63
# 8                 prevailing_wage   9.626161e-45
# 9                    unit_of_wage  5.193385e-240
# 10             full_time_position   4.469975e-02
# 11                    case_status   0.000000e+00
# 12  education_of_employee_encoded   0.000000e+00
#
#                              Result
# 0   Fails to reject null hypothesis
# 1           Rejects null hypothesis
# 2           Rejects null hypothesis
# 3           Rejects null hypothesis
# 4   Fails to reject null hypothesis
# 5   Fails to reject null hypothesis
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
numeric_df = df.select_dtypes(include=['int64', 'float64'])
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(numeric_df.values, i) for i in range(numeric_df.shape[1])]
vif['Feature'] = numeric_df.columns
print(vif)
# Out:
#         VIF                        Feature
# 0  1.061530                no_of_employees
# 1  4.126385                    yr_of_estab
# 2  2.994027                prevailing_wage
# 3  2.228762  education_of_employee_encoded

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# Assuming df is your DataFrame

# Calculate VIF
numeric_df = df.select_dtypes(include=['int64', 'float64'])
vif = pd.DataFrame(columns=['Feature', 'VIF'])
for i in range(numeric_df.shape[1]):
    X = numeric_df.drop(numeric_df.columns[i], axis=1)
    y = numeric_df[numeric_df.columns[i]]
    model = LinearRegression().fit(X, y)
    y_pred = model.predict(X)
    resid = y - y_pred
    vif_value = 1 / (1 - np.var(resid) / np.var(y))
    vif = pd.concat([vif, pd.DataFrame({'Feature': [numeric_df.columns[i]], 'VIF': [vif_value]})], ignore_index=True)

print(vif)

# Calculate Tolerance
tolerance = pd.DataFrame(columns=['Feature', 'Tolerance'])
for i in range(numeric_df.shape[1]):
    X = numeric_df.drop(numeric_df.columns[i], axis=1)
    y = numeric_df[numeric_df.columns[i]]
    model = LinearRegression().fit(X, y)
    y_pred = model.predict(X)
    r2 = 1 - (np.sum((y - y_pred) ** 2) / np.sum((y - np.mean(y)) ** 2))
    tolerance_value = 1 - r2
    tolerance = pd.concat([tolerance, pd.DataFrame({'Feature': [numeric_df.columns[i]], 'Tolerance': [tolerance_value]})], ignore_index=True)

print(tolerance)
# Out:
# C:\Users\riswa\AppData\Local\Temp\ipykernel_14448\1401584025.py:17: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#                          Feature          VIF
# 0                no_of_employees  1480.558917
# 1                    yr_of_estab  1936.950299
# 2                prevailing_wage   401.533545
# 3  education_of_employee_encoded   390.977665
#                          Feature  Tolerance
# 0                no_of_employees   0.999325
# 1                    yr_of_estab   0.999484
# 2                prevailing_wage   0.997510
# 3  education_of_employee_encoded   0.997442
# C:\Users\riswa\AppData\Local\Temp\ipykernel_14448\1401584025.py:30: FutureWarning:
#
# ...

# %%
clr1 = ['#1E90FF', '#DC143C']
fig, ax = plt.subplots(3, 2, figsize=(10,12))
fig.suptitle('Distribution of Numerical Features By Case Status', color='#3C3744',
             fontsize=20, fontweight='bold', ha='center')
for i, col in enumerate(continuous_features):   
    sns.boxplot(data=df, x='case_status', y=col,  palette=clr1, ax=ax[i,0])
    ax[i,0].set_title(f'Boxplot of {col}', fontsize=12)
    sns.histplot(data=df, x=col, hue='case_status', bins=20, kde=True, 
                 multiple='stack', palette=clr1, ax=ax[i,1])
    ax[i,1].set_title(f'Histogram of {col}', fontsize=14)
fig.tight_layout()
fig.subplots_adjust(top=0.90)
# plt.savefig('images/multivariate_num.png')
# Out:
# C:\Users\riswa\AppData\Local\Temp\ipykernel_14448\2516622071.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\riswa\AppData\Local\Temp\ipykernel_14448\2516622071.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\riswa\AppData\Local\Temp\ipykernel_14448\2516622071.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
percentage = df.case_status.value_counts(normalize=True)*100
labels = ["Certified","Denied"]

# Plot PieChart with Ploty library
fig, ax = plt.subplots(figsize =(15, 8))
explode = (0, 0.1)
colors = ['#1188ff','#e63a2a']
ax.pie(percentage, labels = labels, startangle = 90,
       autopct='%1.2f%%',explode=explode, shadow=True, colors=colors)
plt.show()

# %%
#group data by continent and their count of case_status
df.groupby('continent')['case_status'].value_counts(normalize=True).to_frame()*100
# Out:
#                            proportion
# continent     case_status
# Africa        Certified     72.050817
#               Denied        27.949183
# Asia          Certified     65.310480
#               Denied        34.689520
# Europe        Certified     79.233655
#               Denied        20.766345
# North America Certified     61.877278
#               Denied        38.122722
# Oceania       Certified     63.541667
#               Denied        36.458333
# South America Certified     57.863850
#               Denied        42.136150

# %%
plt.subplots(figsize=(14,7))
sns.countplot(x="continent",hue="case_status", data=df, ec = "black",palette="Accent")
plt.title("Continent vs Visa Status", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("Continents", weight="bold", fontsize=16)
plt.legend(title="Visa Status", fancybox=True)
plt.show()

# %%
df2 = df.copy()
plt.figure(figsize=[14,7])

(100*df2[df2["case_status"].isin(['Certified'])]['continent'].value_counts()/df2['continent'].value_counts()).plot(
    kind='bar',stacked=True , colormap='Accent')
plt.title("Percentage of Certified" , fontsize = 15, fontweight ='bold'  )
order1 = (100*df2[df2["case_status"].isin(['Certified'])]['continent'].value_counts()/df2['continent'].value_counts())
for n in range(order1.shape[0]):
    count = order1[n]
    strt='{:0.1f}%'.format(count)
    plt.text(n,count+0.1,strt,ha='center')

plt.xlabel('Continent' , fontweight ='bold')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\riswa\AppData\Local\Temp\ipykernel_14448\1631744176.py:9: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
#group data by Education and their count of case_status
df.groupby('education_of_employee')['case_status'].value_counts(normalize=True).to_frame()*100
# Out:
#                                    proportion
# education_of_employee case_status
# Bachelor's            Certified     62.214188
#                       Denied        37.785812
# Doctorate             Certified     87.226277
#                       Denied        12.773723
# High School           Denied        65.964912
#                       Certified     34.035088
# Master's              Certified     78.627777
#                       Denied        21.372223

# %%
plt.subplots(figsize=(14,7))
sns.countplot(x="education_of_employee",hue="case_status", data=df, ec = "black",palette="Accent")
plt.title("Education of Employee vs Visa Status", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("Education of Employee", weight="bold", fontsize=16)
plt.legend(title="Visa Status", fancybox=True)
plt.show()

# %%
plt.figure(figsize=[14,7])

(100*df2[df2["case_status"].isin(['Certified'])]['education_of_employee'].value_counts()/df2['education_of_employee'].value_counts()).plot(
    kind='bar',stacked=True , colormap='Accent')
plt.title("Percentage of Certified vs Education of the employee" , fontsize = 15, fontweight ='bold'  )
order1 = (100*df2[df2["case_status"].isin(['Certified'])]['education_of_employee'].value_counts()/df2['education_of_employee'].value_counts())
for n in range(order1.shape[0]):
    count = order1[n]
    strt='{:0.1f}%'.format(count)
    plt.text(n,count+0.1,strt,ha='center')

plt.xlabel('education_of_employee' , fontweight ='bold')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\riswa\AppData\Local\Temp\ipykernel_14448\1356139597.py:8: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
